# %%
#Import library 
from sklearn import datasets
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist
import matplotlib.pyplot as plt

# %%
# Import library yang diperlukan
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# Load data iris
iris = load_iris()
features = iris.data

# Plot scatter untuk dua fitur pertama
plt.scatter(features[:, 0], features[:, 1])
plt.xlabel(iris.feature_names[0])  # Memberikan label pada sumbu X
plt.ylabel(iris.feature_names[1])  # Memberikan label pada sumbu Y
plt.title("Scatter Plot of Iris Dataset")
plt.show()

# %%
#Standarisasi fitur
scaler = StandardScaler()
features_standardized = scaler.fit_transform(features)

# %%
from sklearn.metrics import silhouette_samples, silhouette_score 
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(features)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#melakukan klastering
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(features)
plt.scatter(features[:,0], features[:,1])
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=300, c='red')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import cm
import time
import itertools

#baca dataset dari file
datasetPath = ""
dataset = np.loadtxt(datasetPath, delimiter="")

#mendefinikan parameter k-means klustering
k = 2 #jumlah klaster yang diinginkan
iterationCounter = 0 #counter untuk iterasi
input = dataset #input data

#fungsi untuk inisialisasi titik pusat klaster (random)
def initCentroid(dataIn, k):
    result = dataIn[np.random.choice(dataIn.shape[0], k, replace=False)]
    return result

# %%
#import library
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

# %%
dataset = pd.read_csv('Konsumen.csv')
dataset.keys()
# Out:
# Index(['Gaji', 'Pengeluaran'], dtype='object')

# %%
#tampil 5 baris pertama
dataku = pd.DataFrame(dataset)
dataku.head()
# Out:
#    Gaji  Pengeluaran
# 0  2500         1750
# 1  3800         4200
# 2  3900         3800
# 3  4350         5500
# 4  4400         3200

# %%
#konversi dataset ke data array
X = np.asarray(dataset)
print(X)
# Out:
# [[ 2500  1750]
#  [ 3800  4200]
#  [ 3900  3800]
#  [ 4350  5500]
#  [ 4400  3200]
#  [ 5500  5450]
#  [ 5600  5950]
#  [ 5750  4100]
#  [ 6850  6050]
#  [ 6900  8500]
#  [ 7250  9500]
#  [ 7350  6050]
#  [ 7500  8500]
#  [ 7800  9500]
#  [ 8200  8300]
#  [ 8500  6500]
#  [ 8550  8400]
#  [ 8750  6000]
#  [ 9100 10500]
#  [ 9100  8500]]

# %%
#Menampilkan data Array ke dalam Scatter Plot
plt.scatter(X[:,0], X[:,1], label='True Position')
plt.xlabel("Gaji")
plt.ylabel("Pengeluaran")
plt. title("Grafik Persebaran data Konsumen")
plt.show()

# %%
#Mengaktifkan K-Means dengan jumlah k=2
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
#Menampilkan nilai Centroid yang digenerate oleh algoritma
print(kmeans.cluster_centers_)
# Out:
# [[7987.5  8025.  ]
#  [4475.   4243.75]]

# %%
#Plot Data Point
#Memvisualisasikan Hasil Klasterisasi Data Konsumen
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.xlabel("Gaji")
plt.ylabel("Pengeluaran")
plt. title("Grafik Hasil Klasterisasi data gaji dan pengeluaran Konsumen")
plt.show()

# %%
#Plot Data Point
#Memvisualisasikan Hasil Klasterisasi Data Konsumen dengan centroid dari masing masing klaster
plt.scatter(X[:,0], X[:,1], c=kmeans.labels_, cmap='rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmenas.cluster_centers_[:,1]
plt.xlabel("Gaji")
plt.ylabel("Pengeluaran")
plt. title("Grafik Hasil Klasterisasi data gaji dan pengeluaran Konsumen")
plt.show()
